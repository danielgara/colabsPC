# %% [markdown]
# **Listas**

# %%
edades = [28,40,38,90]

# %% [markdown]
# **Ejemplo de definición de una lista**

# %%
nombres = ["Juan", "Carla", "Luisillo"]

print(nombres)
print(type(nombres))
# Out:
# ['Juan', 'Carla', 'Luisillo']
# <class 'list'>

# %% [markdown]
# **Listas con múltiples tipos de datos**

# %%
edadesDeMisAmigos = [10, 15, 20, 40]
misDatos = ["Ana", 36, "ana@eafit.edu.co", 1.60]

# %% [markdown]
# **Visualización de listas en memoria**

# %%
misDatos = ["Ana", 36, 1.60]

# %% [markdown]
# **Valores y referencias en memoria**

# %%
nombre = "Ana"
edad = 28
gustos = ["leer"]

# %% [markdown]
# **Acceder a elementos de una lista**

# %%
misNotas = [1.5, 4.0, 5.0, 2.2]

print(misNotas[0])
print(misNotas[len(misNotas)-1])
print(type(misNotas[2]))
# Out:
# 1.5
# 2.2
# <class 'float'>

# %% [markdown]
# **Acceder a elementos de una lista – Ejercicio - Error**

# %%
misNotas = [1.5, 4.0, 5.0, 2.2]

print(misNotas[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-f4170594c17d> in <module>()
#       1 misNotas = [1.5, 4.0, 5.0, 2.2]
#       2
# ----> 3 print(misNotas[4])
#
# IndexError: list index out of range

# %% [markdown]
# **Modificar elementos de una lista**

# %%
motocicletas = ["Honda", "Yamaha", "Suzuki"]
print(motocicletas[0])

motocicletas[0] = "Ducati"
print(motocicletas[0])
# Out:
# Honda
# Ducati

# %% [markdown]
# **Agregar elementos a una lista**

# %%
aliens = []
aliens.append("E.T.")
aliens.append("Goku")
aliens.append("Marvin")
aliens.append("Gazoo")
print(aliens[3])
# Out:
# Gazoo

# %% [markdown]
# **Eliminar elementos de una lista**

# %%
aliens = ["E.T.", "Goku", "Marvin", "Gazoo"]
print(aliens[1])
aliens.pop(1)
print(aliens[1])
# Out:
# Goku
# Marvin

# %% [markdown]
# **Ciclos con listas**

# %%
aliens = ["E.T.", "Goku", "Marvin", "Gazoo"]

i = 0
while(i < len(aliens)):
  print(aliens[i])
  i = i+1
# Out:
# E.T.
# Goku
# Marvin
# Gazoo

# %% [markdown]
# **Ejercicio de clase 1**

# %%
videojuegos = []

juego1 = input("Ingrese nombre juego: ")
juego2 = input("Ingrese nombre juego: ")

videojuegos.append(juego1)
videojuegos.append(juego2)
videojuegos.append("GTA V")

i = 0
while(i < len(videojuegos)):
  print(videojuegos[i])
  i = i+1
# Out:
# Ingrese nombre juego: Valorant
# Ingrese nombre juego: Dark Souls
# Valorant
# Dark Souls
# GTA V
